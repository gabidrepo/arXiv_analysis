# %% [markdown]
# # Load the data set

# %%
import json
import re

# Load the dataset containing metadata from arXiv
dataset = "/kaggle/input/arxiv/arxiv-metadata-oai-snapshot.json"

# %%
import pandas as pd

# Read the JSON file into a Pandas DataFrame
arxiv_df = pd.read_json(dataset, lines=True)
print(len(arxiv_df))

# Drop unnecessary columns
arxiv_df.drop(columns=['journal-ref', 'doi','report-no','submitter','license','comments'], inplace=True)
# Remove rows with missing values
arxiv_df.dropna(inplace=True)
print(len(arxiv_df))
# Out:
# 2468403
# 2468403

# %%
# Show the columns
print (arxiv_df.columns)
# Out:
# Index(['id', 'authors', 'title', 'categories', 'abstract', 'versions',
#        'update_date', 'authors_parsed'],
#       dtype='object')

# %%
# Show the datafarme
arxiv_df
# Out:
#                        id                                            authors  \
# 0               0704.0001  C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1               0704.0002                    Ileana Streinu and Louis Theran
# 2               0704.0003                                        Hongjun Pan
# 3               0704.0004                                       David Callan
# 4               0704.0005           Wael Abu-Shammala and Alberto Torchinsky
# ...                   ...                                                ...
# 2468398  supr-con/9608008  R. Prozorov, M. Konczykowski, B. Schmidt, Y. Y...
# 2468399  supr-con/9609001  Durga P. Choudhury, Balam A. Willemsen, John S...
# 2468400  supr-con/9609002  Balam A. Willemsen, J. S. Derov and S.Sridhar ...
# 2468401  supr-con/9609003  Yasumasa Hasegawa (Himeji Institute of Technol...
# 2468402  supr-con/9609004  Naoki Enomoto, Masanori Ichioka and Kazushige ...
#
#                                                      title  \
# 0        Calculation of prompt diphoton production cros...
# 1                 Sparsity-certifying Graph Decompositions
# 2        The evolution of the Earth-Moon system based o...
# 3        A determinant of Stirling cycle numbers counts...
# 4        From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
# ...                                                    ...
# 2468398  On the origin of the irreversibility line in t...
# 2468399  Nonlinear Response of HTSC Thin Film Microwave...
# 2468400  Critical State Flux Penetration and Linear Mic...
# 2468401  Density of States and NMR Relaxation Rate in A...
# 2468402  Ginzburg Landau theory for d-wave pairing and ...
#
#                          categories  \
# 0                            hep-ph
# 1                     math.CO cs.CG
# 2                    physics.gen-ph
# 3                           math.CO
# 4                   math.CA math.FA
# ...                             ...
# 2468398  supr-con cond-mat.supr-con
# 2468399  supr-con cond-mat.supr-con
# 2468400  supr-con cond-mat.supr-con
# 2468401  supr-con cond-mat.supr-con
# 2468402  supr-con cond-mat.supr-con
#
#                                                   abstract  \
# 0          A fully differential calculation in perturba...
# 1          We describe a new algorithm, the $(k,\ell)$-...
# 2          The evolution of Earth-Moon system is descri...
# 3          We show that a determinant of Stirling cycle...
# 4          In this paper we show how to compute the $\L...
# ...                                                    ...
# 2468398    We report on measurements of the angular dep...
# 2468399    The non-linear microwave surface impedance o...
# 2468400    The vortex contribution to the dc field (H) ...
# 2468401    We show that the density of states in an ani...
# 2468402    The Ginzburg Landau theory for d_{x^2-y^2}-w...
#
#                                                   versions update_date  \
# 0        [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2008-11-26
# 1        [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2008-12-13
# 2        [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...  2008-01-13
# 3        [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2007-05-23
# 4        [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2013-10-15
# ...                                                    ...         ...
# 2468398  [{'version': 'v1', 'created': 'Mon, 26 Aug 199...  2009-10-30
# 2468399  [{'version': 'v1', 'created': 'Sat, 31 Aug 199...  2016-11-18
# 2468400  [{'version': 'v1', 'created': 'Tue, 3 Sep 1996...  2009-10-30
# 2468401  [{'version': 'v1', 'created': 'Wed, 18 Sep 199...  2009-10-30
# 2468402  [{'version': 'v1', 'created': 'Wed, 25 Sep 199...  2009-10-30
#
#                                             authors_parsed
# 0        [[Balázs, C., ], [Berger, E. L., ], [Nadolsky,...
# 1                 [[Streinu, Ileana, ], [Theran, Louis, ]]
# 2                                       [[Pan, Hongjun, ]]
# 3                                      [[Callan, David, ]]
# 4        [[Abu-Shammala, Wael, ], [Torchinsky, Alberto, ]]
# ...                                                    ...
# 2468398  [[Prozorov, R., ], [Konczykowski, M., ], [Schm...
# 2468399  [[Choudhury, Durga P., , Physics Department, N...
# 2468400  [[Willemsen, Balam A., , Physics Department,\n...
# 2468401  [[Hasegawa, Yasumasa, , Himeji Institute of Te...
# 2468402  [[Enomoto, Naoki, , Okayama Univ.], [Ichioka, ...
#
# [2468403 rows x 8 columns]

# %%
# Function to count the number of authors
def count_authors(authors_list):
    return len(authors_list)

# Apply the count_authors function to create a new column 'num_authors' in the DataFrame
arxiv_df['num_authors'] = arxiv_df['authors_parsed'].apply(count_authors)
arxiv_df
# Out:
#                        id                                            authors  \
# 0               0704.0001  C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1               0704.0002                    Ileana Streinu and Louis Theran
# 2               0704.0003                                        Hongjun Pan
# 3               0704.0004                                       David Callan
# 4               0704.0005           Wael Abu-Shammala and Alberto Torchinsky
# ...                   ...                                                ...
# 2468398  supr-con/9608008  R. Prozorov, M. Konczykowski, B. Schmidt, Y. Y...
# 2468399  supr-con/9609001  Durga P. Choudhury, Balam A. Willemsen, John S...
# 2468400  supr-con/9609002  Balam A. Willemsen, J. S. Derov and S.Sridhar ...
# 2468401  supr-con/9609003  Yasumasa Hasegawa (Himeji Institute of Technol...
# 2468402  supr-con/9609004  Naoki Enomoto, Masanori Ichioka and Kazushige ...
#
#                                                      title  \
# 0        Calculation of prompt diphoton production cros...
# 1                 Sparsity-certifying Graph Decompositions
# 2        The evolution of the Earth-Moon system based o...
# 3        A determinant of Stirling cycle numbers counts...
# 4        From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
# ...                                                    ...
# 2468398  On the origin of the irreversibility line in t...
# 2468399  Nonlinear Response of HTSC Thin Film Microwave...
# 2468400  Critical State Flux Penetration and Linear Mic...
# 2468401  Density of States and NMR Relaxation Rate in A...
# 2468402  Ginzburg Landau theory for d-wave pairing and ...
#
#                          categories  \
# 0                            hep-ph
# 1                     math.CO cs.CG
# 2                    physics.gen-ph
# 3                           math.CO
# 4                   math.CA math.FA
# ...                             ...
# 2468398  supr-con cond-mat.supr-con
# 2468399  supr-con cond-mat.supr-con
# 2468400  supr-con cond-mat.supr-con
# 2468401  supr-con cond-mat.supr-con
# 2468402  supr-con cond-mat.supr-con
#
#                                                   abstract  \
# 0          A fully differential calculation in perturba...
# 1          We describe a new algorithm, the $(k,\ell)$-...
# 2          The evolution of Earth-Moon system is descri...
# 3          We show that a determinant of Stirling cycle...
# 4          In this paper we show how to compute the $\L...
# ...                                                    ...
# 2468398    We report on measurements of the angular dep...
# 2468399    The non-linear microwave surface impedance o...
# 2468400    The vortex contribution to the dc field (H) ...
# 2468401    We show that the density of states in an ani...
# 2468402    The Ginzburg Landau theory for d_{x^2-y^2}-w...
#
#                                                   versions update_date  \
# 0        [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2008-11-26
# 1        [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2008-12-13
# 2        [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...  2008-01-13
# 3        [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2007-05-23
# 4        [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2013-10-15
# ...                                                    ...         ...
# 2468398  [{'version': 'v1', 'created': 'Mon, 26 Aug 199...  2009-10-30
# 2468399  [{'version': 'v1', 'created': 'Sat, 31 Aug 199...  2016-11-18
# 2468400  [{'version': 'v1', 'created': 'Tue, 3 Sep 1996...  2009-10-30
# 2468401  [{'version': 'v1', 'created': 'Wed, 18 Sep 199...  2009-10-30
# 2468402  [{'version': 'v1', 'created': 'Wed, 25 Sep 199...  2009-10-30
#
#                                             authors_parsed  num_authors
# 0        [[Balázs, C., ], [Berger, E. L., ], [Nadolsky,...            4
# 1                 [[Streinu, Ileana, ], [Theran, Louis, ]]            2
# 2                                       [[Pan, Hongjun, ]]            1
# 3                                      [[Callan, David, ]]            1
# 4        [[Abu-Shammala, Wael, ], [Torchinsky, Alberto, ]]            2
# ...                                                    ...          ...
# 2468398  [[Prozorov, R., ], [Konczykowski, M., ], [Schm...            7
# 2468399  [[Choudhury, Durga P., , Physics Department, N...            4
# 2468400  [[Willemsen, Balam A., , Physics Department,\n...            3
# 2468401  [[Hasegawa, Yasumasa, , Himeji Institute of Te...            1
# 2468402  [[Enomoto, Naoki, , Okayama Univ.], [Ichioka, ...            3
#
# [2468403 rows x 9 columns]

# %% [markdown]
# # Show the chart of average authors count per year

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Convert 'update_date' to datetime format
arxiv_df['update_date'] = pd.to_datetime(arxiv_df['update_date'])

# Extract year from the 'update_date' column
arxiv_df['year'] = arxiv_df['update_date'].dt.year

# Group by year and calculate the average author count
average_author_count_by_year = arxiv_df.groupby('year')['num_authors'].mean().reset_index()

# Plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='year', y='num_authors', data=average_author_count_by_year, color='skyblue',zorder=0)

sns.despine(offset=10, trim=False)
plt.title('Average authors count by year')
plt.xlabel('Year')
plt.ylabel('Average author count')
plt.xticks(rotation=45)
plt.grid(axis='y')  # Add gridlines on y-axis
plt.tight_layout()
plt.savefig('average_authors_count_by_year.png')
# show the chart
plt.show()

# %% [markdown]
# # Show average versions count per year

# %%
# Function to count the number of versions
def count_versions(versions_list):
    return len(versions_list)

# Apply the count_versions function to create a new column 'num_versions' in the DataFrame
arxiv_df['num_versions'] = arxiv_df['versions'].apply(count_versions)

arxiv_df
# Out:
#                        id                                            authors  \
# 0               0704.0001  C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1               0704.0002                    Ileana Streinu and Louis Theran
# 2               0704.0003                                        Hongjun Pan
# 3               0704.0004                                       David Callan
# 4               0704.0005           Wael Abu-Shammala and Alberto Torchinsky
# ...                   ...                                                ...
# 2468398  supr-con/9608008  R. Prozorov, M. Konczykowski, B. Schmidt, Y. Y...
# 2468399  supr-con/9609001  Durga P. Choudhury, Balam A. Willemsen, John S...
# 2468400  supr-con/9609002  Balam A. Willemsen, J. S. Derov and S.Sridhar ...
# 2468401  supr-con/9609003  Yasumasa Hasegawa (Himeji Institute of Technol...
# 2468402  supr-con/9609004  Naoki Enomoto, Masanori Ichioka and Kazushige ...
#
#                                                      title  \
# 0        Calculation of prompt diphoton production cros...
# 1                 Sparsity-certifying Graph Decompositions
# 2        The evolution of the Earth-Moon system based o...
# 3        A determinant of Stirling cycle numbers counts...
# 4        From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
# ...                                                    ...
# 2468398  On the origin of the irreversibility line in t...
# 2468399  Nonlinear Response of HTSC Thin Film Microwave...
# 2468400  Critical State Flux Penetration and Linear Mic...
# 2468401  Density of States and NMR Relaxation Rate in A...
# 2468402  Ginzburg Landau theory for d-wave pairing and ...
#
#                          categories  \
# 0                            hep-ph
# 1                     math.CO cs.CG
# 2                    physics.gen-ph
# 3                           math.CO
# 4                   math.CA math.FA
# ...                             ...
# 2468398  supr-con cond-mat.supr-con
# 2468399  supr-con cond-mat.supr-con
# 2468400  supr-con cond-mat.supr-con
# 2468401  supr-con cond-mat.supr-con
# 2468402  supr-con cond-mat.supr-con
#
#                                                   abstract  \
# 0          A fully differential calculation in perturba...
# 1          We describe a new algorithm, the $(k,\ell)$-...
# 2          The evolution of Earth-Moon system is descri...
# 3          We show that a determinant of Stirling cycle...
# 4          In this paper we show how to compute the $\L...
# ...                                                    ...
# 2468398    We report on measurements of the angular dep...
# 2468399    The non-linear microwave surface impedance o...
# 2468400    The vortex contribution to the dc field (H) ...
# 2468401    We show that the density of states in an ani...
# 2468402    The Ginzburg Landau theory for d_{x^2-y^2}-w...
#
#                                                   versions update_date  \
# 0        [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2008-11-26
# 1        [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2008-12-13
# 2        [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...  2008-01-13
# 3        [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2007-05-23
# 4        [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2013-10-15
# ...                                                    ...         ...
# 2468398  [{'version': 'v1', 'created': 'Mon, 26 Aug 199...  2009-10-30
# 2468399  [{'version': 'v1', 'created': 'Sat, 31 Aug 199...  2016-11-18
# 2468400  [{'version': 'v1', 'created': 'Tue, 3 Sep 1996...  2009-10-30
# 2468401  [{'version': 'v1', 'created': 'Wed, 18 Sep 199...  2009-10-30
# 2468402  [{'version': 'v1', 'created': 'Wed, 25 Sep 199...  2009-10-30
#
#                                             authors_parsed  num_authors  year  \
# 0        [[Balázs, C., ], [Berger, E. L., ], [Nadolsky,...            4  2008
# 1                 [[Streinu, Ileana, ], [Theran, Louis, ]]            2  2008
# 2                                       [[Pan, Hongjun, ]]            1  2008
# 3                                      [[Callan, David, ]]            1  2007
# 4        [[Abu-Shammala, Wael, ], [Torchinsky, Alberto, ]]            2  2013
# ...                                                    ...          ...   ...
# 2468398  [[Prozorov, R., ], [Konczykowski, M., ], [Schm...            7  2009
# 2468399  [[Choudhury, Durga P., , Physics Department, N...            4  2016
# 2468400  [[Willemsen, Balam A., , Physics Department,\n...            3  2009
# 2468401  [[Hasegawa, Yasumasa, , Himeji Institute of Te...            1  2009
# 2468402  [[Enomoto, Naoki, , Okayama Univ.], [Ichioka, ...            3  2009
#
#          num_versions
# 0                   2
# 1                   2
# 2                   3
# 3                   1
# 4                   1
# ...               ...
# 2468398             1
# 2468399             1
# 2468400             1
# 2468401             1
# 2468402             1
#
# [2468403 rows x 11 columns]

# %%
# Group by year and calculate the average verisons count
average_versions_count_by_year = arxiv_df.groupby('year')['num_versions'].mean().reset_index()

# Plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='year', y='num_versions', data=average_versions_count_by_year, color='skyblue')
plt.title('Average versions count by year')
plt.xlabel('Year')
plt.ylabel('Average Vvrsions count')
plt.xticks(rotation=45)
plt.grid(axis='y')  # Add gridlines on y-axis
plt.tight_layout()
plt.savefig('average_versions_count_by_year.png')
plt.show()

# %%
# Install packages for web scraping
# !pip install beautifulsoup4
# !pip install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests) (2024.2.2)

# %% [markdown]
# Getting the sub-category name

# %%
import requests
from bs4 import BeautifulSoup

# Send an HTTP GET request to the URL
response = requests.get("https://arxiv.org/category_taxonomy")

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the div containing the category taxonomy
    taxonomy_div = soup.find('div', id='category_taxonomy_list')
    
    # Initialize an empty dictionary to store the sub-category and its father category
    category_dict = {}
    
    # Find all h2 tags (father categories)
#     father_categories = taxonomy_div.find_all(['h2','h3'], class_='accordion-head')
    father_categories_h2 = taxonomy_div.find_all('h2', class_='accordion-head')
    father_categories_h3 = taxonomy_div.find_all('h3', class_='column is-one-fifth')
    
    # Combine both lists of father categories
    father_categories = father_categories_h2 + father_categories_h3
    
    # Iterate over each father category
    for father_category in father_categories:
        # Extract father category name
        father_category_name = father_category.text.strip()
        
        # Find all h4 tags (sub-categories) within the current father category
        sub_categories = father_category.find_next_sibling().find_all('h4')

        # Iterate over each sub-category
        for sub_category in sub_categories:
            # Extract sub-category name
            sub_category_name = sub_category.text.strip()
            
            # Extract sub-category code
            sub_category_code = sub_category_name.split()[0]
            
            # Add the sub-category and its father category to the dictionary
            category_dict[sub_category_code] = father_category_name

    # Display the dictionary
    print(category_dict)
else:
    # Display an error message if the request was not successful
    print("Failed to retrieve webpage content. Status code:", response.status_code)
# Out:
# {'cs.AI': 'Computer Science', 'cs.AR': 'Computer Science', 'cs.CC': 'Computer Science', 'cs.CE': 'Computer Science', 'cs.CG': 'Computer Science', 'cs.CL': 'Computer Science', 'cs.CR': 'Computer Science', 'cs.CV': 'Computer Science', 'cs.CY': 'Computer Science', 'cs.DB': 'Computer Science', 'cs.DC': 'Computer Science', 'cs.DL': 'Computer Science', 'cs.DM': 'Computer Science', 'cs.DS': 'Computer Science', 'cs.ET': 'Computer Science', 'cs.FL': 'Computer Science', 'cs.GL': 'Computer Science', 'cs.GR': 'Computer Science', 'cs.GT': 'Computer Science', 'cs.HC': 'Computer Science', 'cs.IR': 'Computer Science', 'cs.IT': 'Computer Science', 'cs.LG': 'Computer Science', 'cs.LO': 'Computer Science', 'cs.MA': 'Computer Science', 'cs.MM': 'Computer Science', 'cs.MS': 'Computer Science', 'cs.NA': 'Computer Science', 'cs.NE': 'Computer Science', 'cs.NI': 'Computer Science', 'cs.OH': 'Computer Science', 'cs.OS': 'Computer Science', 'cs.PF': 'Computer Science', 'cs.PL': 'Computer Science', 'cs.RO': 'Computer Science', 'cs.SC': 'Computer Science', 'cs.SD': 'Computer Science', 'cs.SE': 'Computer Science', 'cs.SI': 'Computer Science', 'cs.SY': 'Computer Science', 'econ.EM': 'Economics', 'econ.GN': 'Economics', 'econ.TH': 'Economics', 'eess.AS': 'Electrical Engineering and Systems Science', 'eess.IV': 'Electrical Engineering and Systems Science', 'eess.SP': 'Electrical Engineering and Systems Science', 'eess.SY': 'Electrical Engineering and Systems Science', 'math.AC': 'Mathematics', 'math.AG': 'Mathematics', 'math.AP': 'Mathematics', 'math.AT': 'Mathematics', 'math.CA': 'Mathematics', 'math.CO': 'Mathematics', 'math.CT': 'Mathematics', 'math.CV': 'Mathematics', 'math.DG': 'Mathematics', 'math.DS': 'Mathematics', 'math.FA': 'Mathematics', 'math.GM': 'Mathematics', 'math.GN': 'Mathematics', 'math.GR': 'Mathematics', 'math.GT': 'Mathematics', 'math.HO': 'Mathematics', 'math.IT': 'Mathematics', 'math.KT': 'Mathematics', 'math.LO': 'Mathematics', 'math.MG': 'Mathematics', 'math.MP': 'Mathematics', 'math.NA': 'Mathematics', 'math.NT': 'Mathematics', 'math.OA': 'Mathematics', 'math.OC': 'Mathematics', 'math.PR': 'Mathematics', 'math.QA': 'Mathematics', 'math.RA': 'Mathematics', 'math.RT': 'Mathematics', 'math.SG': 'Mathematics', 'math.SP': 'Mathematics', 'math.ST': 'Mathematics', 'astro-ph.CO': 'Physics', 'astro-ph.EP': 'Physics', 'astro-ph.GA': 'Physics', 'astro-ph.HE': 'Physics', 'astro-ph.IM': 'Physics', 'astro-ph.SR': 'Physics', 'cond-mat.dis-nn': 'Physics', 'cond-mat.mes-hall': 'Physics', 'cond-mat.mtrl-sci': 'Physics', 'cond-mat.other': 'Physics', 'cond-mat.quant-gas': 'Physics', 'cond-mat.soft': 'Physics', 'cond-mat.stat-mech': 'Physics', 'cond-mat.str-el': 'Physics', 'cond-mat.supr-con': 'Physics', 'gr-qc': 'Physics', 'hep-ex': 'Physics', 'hep-lat': 'Physics', 'hep-ph': 'Physics', 'hep-th': 'Physics', 'math-ph': 'Physics', 'nlin.AO': 'Physics', 'nlin.CD': 'Physics', 'nlin.CG': 'Physics', 'nlin.PS': 'Physics', 'nlin.SI': 'Physics', 'nucl-ex': 'Physics', 'nucl-th': 'Physics', 'physics.acc-ph': 'Physics', 'physics.ao-ph': 'Physics', 'physics.app-ph': 'Physics', 'physics.atm-clus': 'Physics', 'physics.atom-ph': 'Physics', 'physics.bio-ph': 'Physics', 'physics.chem-ph': 'Physics', 'physics.class-ph': 'Physics', 'physics.comp-ph': 'Physics', 'physics.data-an': 'Physics', 'physics.ed-ph': 'Physics', 'physics.flu-dyn': 'Physics', 'physics.gen-ph': 'Physics', 'physics.geo-ph': 'Physics', 'physics.hist-ph': 'Physics', 'physics.ins-det': 'Physics', 'physics.med-ph': 'Physics', 'physics.optics': 'Physics', 'physics.plasm-ph': 'Physics', 'physics.pop-ph': 'Physics', 'physics.soc-ph': 'Physics', 'physics.space-ph': 'Physics', 'quant-ph': 'Physics', 'q-bio.BM': 'Quantitative Biology', 'q-bio.CB': 'Quantitative Biology', 'q-bio.GN': 'Quantitative Biology', 'q-bio.MN': 'Quantitative Biology', 'q-bio.NC': 'Quantitative Biology', 'q-bio.OT': 'Quantitative Biology', 'q-bio.PE': 'Quantitative Biology', 'q-bio.QM': 'Quantitative Biology', 'q-bio.SC': 'Quantitative Bio ...

# %% [markdown]
# Getting the top-category name

# %%
import requests
from bs4 import BeautifulSoup

# URL of the website
url = "https://arxiv.org/category_taxonomy"

# Send an HTTP request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all relevant HTML elements (all <h4> elements)
    category_elements = soup.find_all(['h3','h4'])

    # Create a dictionary to store key-value pairs
    categories_dict = {}

    # Extract information and populate the dictionary
    for category_element in category_elements:
        category_key = category_element.text.strip().split()[0]
        
        # Check if there is a <span> element
        span_element = category_element.find('span')
        if span_element:
            category_value = span_element.text.strip()
        else:
            category_value = "No Value Found"
        
        if (category_value!="No Value Found"):
            categories_dict[category_key] = category_value.strip(')').strip('(')

    # Print the key-value pairs
    for key, value in categories_dict.items():
        print(f"Key: {key}")
        print(f"Value: {value}")
        print()

else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
# Key: cs.AI
# Value: Artificial Intelligence
#
# Key: cs.AR
# Value: Hardware Architecture
#
# Key: cs.CC
# Value: Computational Complexity
#
# Key: cs.CE
# Value: Computational Engineering, Finance, and Science
#
# Key: cs.CG
# Value: Computational Geometry
#
# Key: cs.CL
# Value: Computation and Language
#
# Key: cs.CR
# Value: Cryptography and Security
#
# Key: cs.CV
# Value: Computer Vision and Pattern Recognition
#
# Key: cs.CY
# Value: Computers and Society
#
# Key: cs.DB
# Value: Databases
#
# Key: cs.DC
# Value: Distributed, Parallel, and Cluster Computing
#
# Key: cs.DL
# Value: Digital Libraries
#
# Key: cs.DM
# Value: Discrete Mathematics
#
# Key: cs.DS
# Value: Data Structures and Algorithms
#
# Key: cs.ET
# Value: Emerging Technologies
#
# Key: cs.FL
# Value: Formal Languages and Automata Theory
#
# Key: cs.GL
# Value: General Literature
#
# Key: cs.GR
# Value: Graphics
#
# Key: cs.GT
# Value: Computer Science and Game Theory
#
# Key: cs.HC
# Value: Human-Computer Interaction
#
# Key: cs.IR
# Value: Information Retrieval
#
# Key: cs.IT
# Value: Information Theory
#
# Key: cs.LG
# Value: Machine Learning
#
# Key: cs.LO
# Value: Logic in Computer Science
#
# Key: cs.MA
# Value: Multiagent Systems
#
# Key: cs.MM
# Value: Multimedia
#
# Key: cs.MS
# Value: Mathematical Software
#
# Key: cs.NA
# Value: Numerical Analysis
#
# Key: cs.NE
# Value: Neural and Evolutionary Computing
#
# Key: cs.NI
# Value: Networking and Internet Architecture
#
# Key: cs.OH
# Value: Other Computer Science
#
# Key: cs.OS
# Value: Operating Systems
#
# Key: cs.PF
# Value: Performance
#
# Key: cs.PL
# Value: Programming Languages
#
# Key: cs.RO
# Value: Robotics
#
# Key: cs.SC
# Value: Symbolic Computation
#
# Key: cs.SD
# Value: Sound
#
# Key: cs.SE
# Value: Software Engineering
#
# Key: cs.SI
# Value: Social and Information Networks
#
# Key: cs.SY
# Value: Systems and Control
#
# Key: econ.EM
# Value: Econometrics
#
# Key: econ.GN
# Value: General Economics
#
# Key: econ.TH
# Value: Theoretical Economics
#
# Key: eess.AS
# Value: Audio and Speech Processing
#
# Key: eess.IV
# Value: Image and Video Processing
#
# Key: eess.SP
# Value: Signal Processing
#
# Key: eess.SY
# Value: Systems and Control
#
# Key: math.AC
# Value: Commutative Algebra
#
# Key: math.AG
# Value: Algebraic Geometry
#
# Key: math.AP
# Value: Analysis of PDEs
#
# Key: math.AT
# Value: Algebraic Topology
#
# Key: math.CA
# Value: Classical Analysis and ODEs
#
# Key: math.CO
# Value: Combinatorics
#
# Key: math.CT
# Value: Category Theory
#
# Key: math.CV
# Value: Complex Variables
#
# Key: math.DG
# Value: Differential Geometry
#
# Key: math.DS
# Value: Dynamical Systems
#
# Key: math.FA
# Value: Functional Analysis
#
# Key: math.GM
# Value: General Mathematics
#
# Key: math.GN
# Value: General Topology
#
# Key: math.GR
# Value: Group Theory
#
# Key: math.GT
# Value: Geometric Topology
#
# Key: math.HO
# Value: History and Overview
#
# Key: math.IT
# Value: Information Theory
#
# Key: math.KT
# Value: K-Theory and Homology
#
# Key: math.LO
# Value: Logic
#
# Key: math.MG
# Value: Metric Geometry
#
# Key: math.MP
# Value: Mathematical Physics
#
# Key: math.NA
# Value: Numerical Analysis
#
# Key: math.NT
# Value: Number Theory
#
# Key: math.OA
# Value: Operator Algebras
#
# Key: math.OC
# Value: Optimization and Control
#
# Key: math.PR
# Value: Probability
#
# Key: math.QA
# Value: Quantum Algebra
#
# Key: math.RA
# Value: Rings and Algebras
#
# Key: math.RT
# Value: Representation Theory
#
# Key: math.SG
# Value: Symplectic Geometry
#
# Key: math.SP
# Value: Spectral Theory
#
# Key: math.ST
# Value: Statistics Theory
#
# Key: Astrophysics(astro-ph)
# Value: astro-ph
#
# Key: astro-ph.CO
# Value: Cosmology and Nongalactic Astrophysics
#
# Key: astro-ph.EP
# Value: Earth and Planetary Astrophysics
#
# Key: astro-ph.GA
# Value: Astrophysics of Galaxies
#
# Key: astro-ph.HE
# Value: High Energy Astrophysical Phenomena
#
# Key: astro-ph.IM
# Value: Instrumentation and Methods for Astrophysics
#
# Key: astro-ph.SR
# Value: Solar and Stellar Astrophysics
#
# Key: Condensed
# Value: cond-mat
#
# Key: cond-mat.dis-nn
# Value: Disordered Systems and Neural Networks
#
# Key: cond-mat.mes-hall
# Value: Mesoscale and Nanoscale Physics
#
# Key: cond-mat.mtrl-sci
# Value: Materials Science
#
# Key: cond-mat.other
# Value: Other Condensed Matter
#
# Key: cond-mat.quant-gas
# Value: Quantum Gases
#
# Key: cond-mat.soft
# Value: Soft Condensed Matter
#
# Key: cond-mat.stat-mech
# Value: Statistical Mechanics
#
# Key: cond-mat.str-el
# Value: Strongly Correlated Electrons
#
# Key: cond-mat.supr-con
# Value: Superconductivity
#
# Key: General
# Value: gr-qc
#
# Key: gr-qc
# Value: General Relativity and Quantum Cosmology
#
# Key: High
# Value: hep-th
#
# Key: hep-ex
# Value: High Energy Physics - Experiment
#
# Key: hep-lat
# Value: High Energy Physics - Lattice
#
# Key: hep-ph
# Value: High Energy Physics - Phenomenology
#
# Key: hep-th
# Value: High Energy Physics - Theory
#
# Key: Mathematical
# Value: math-ph
#
# Key: math-ph
# Value: Mathematical Physics
#
# Key: Nonlinear
# Value: nlin
#
# Key: nlin.AO
# Value: Adaptation and Self-Organizing Systems
#
# Key: nlin.CD
# Value: Chaotic Dynamics
#
# Key: nlin.CG
# Value: Cellular Automata and Lattice Gases
#
# Key: nlin.PS
# Value: Pattern Formation and Solitons
#
# Key: nlin.SI
# Value: Exactly Solvable and Integrable Systems
#
# Key: Nuclear
# Value: nucl-th
#
# Key: nucl-ex
# Value: Nuclear Experiment
#
# Key: nucl-th
# Value: Nuclear Theory
#
# Key: Physics(physics)
# Value: physics
#
# Key: physics.acc-ph
# Value: Accelerator Physics
#
# Key: physics.ao-ph
# Value: Atmospheric and Oceanic Physics
#
# Key: physics.app-ph
# Value: Applied Physics
#
# Key: physics.atm-clus
# Value: Atomic and Molecular Clusters
#
# Key: physics.atom-ph
# Value: Atomic Physics
#
# Key: physics.bio-ph
# Value: Biological Physics
#
# Key: physics.chem-ph
# Value: Chemical Physics
#
# Key: physics.class-ph
# Value: Classical Physics
#
# Key: physics.comp-ph
# Value: Computational Physics
#
# Key: physics.data-an
# Value: Data Analysis, Statistics and Probability
#
# Key: physics.ed-ph
# Value: Physics Education
#
# Key: physics.flu-dyn
# Value: Fluid Dynamics
#
# Key: physics.gen-ph
# Value: General Physics
#
# Key: physics.geo-ph
# Value: Geophysics
#
# Key: physics.hist-ph
# Value: History and Philosophy of Physics
#
# Key: physics.ins-det
# Value: Instrumentation and Detectors
#
# Key: physics.med-ph
# Value: Medical Physics
#
# Key: physics.optics
# Value: Optics
#
# Key: physics.plasm-ph
# Value: Plasma Physics
#
# Key: physics.pop-ph
# Value: Popular Physics
#
# Key: physics.soc-ph
# Value: Physics and Society
#
# Key: physics.space-ph
# Value: Space Physics
#
# Key: Quantum
# Value: quant-ph
#
# Key: quant-ph
# Value: Quantum Physics
#
# Key: q-bio.BM
# Value: Biomolecules
#
# Key: q-bio.CB
# Value: Cell Behavior
#
# Key: q-bio.GN
# Value: Genomics
#
# Key: q-bio.MN
# Value: Molecular Networks
#
# Key: q-bio.NC
# Value: Neurons and Cognition
#
# Key: q-bio.OT
# Value: Other Quantitative Biology
#
# Key: q-bio.PE
# Value: Populations and Evolution
#
# Key: q-bio.QM
# Value: Quantitative Methods
#
# Key: q-bio.SC
# Value: Subcellular Processes
#
# Key: q-bio.TO
# Value: Tissues and Organs
#
# Key: q-fin.CP
# Value: Computational Finance
#
# Key: q-fin.EC
# Value: Economics
#
# Key: q-fin.GN
# Value: General Finance
#
# Key: q-fin.MF
# Value: Mathematical Finance
#
# Key: q-fin.PM
# Value: Portfolio Management
#
# Key: q-fin.PR
# Value: Pricing of Securities
#
# Key: q-fin.RM
# Value: Risk Management
#
# Key: q-fin.ST
# Value: Statistical Finance
#
# Key: q-fin.TR
# Value: Trading and Market Microstructure
#
# Key: stat.AP
# Value: Applications
#
# Key: stat.CO
# Value: Computation
#
# Key: stat.ME
# Value: Methodology
#
# Key: stat.ML
# Value: Machine Learning
#
# Key: stat.OT
# Value: Other Statistics
#
# Key: stat.TH
# Value: Statistics Theory

# %% [markdown]
# # Explode the list of categories into separate rows

# %%
arxiv_df['sep_categories'] = arxiv_df['categories'].str.split()
# Filttering only full year data
arxiv_df= arxiv_df[arxiv_df['year']<2024]
# Explode the list into separate rows
df_exploded = arxiv_df.explode('sep_categories')

# Create a new column with the corresponding values from categories_dict
df_exploded['category'] = df_exploded['sep_categories'].str.strip().map(categories_dict)

# Display the updated DataFrame
print(len(df_exploded))

# Drop rows with missing values
df_exploded.dropna(inplace=True)
# show the dataframe
df_exploded
# Out:
# 3977398
#                        id                                            authors  \
# 0               0704.0001  C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1               0704.0002                    Ileana Streinu and Louis Theran
# 1               0704.0002                    Ileana Streinu and Louis Theran
# 2               0704.0003                                        Hongjun Pan
# 3               0704.0004                                       David Callan
# ...                   ...                                                ...
# 2468398  supr-con/9608008  R. Prozorov, M. Konczykowski, B. Schmidt, Y. Y...
# 2468399  supr-con/9609001  Durga P. Choudhury, Balam A. Willemsen, John S...
# 2468400  supr-con/9609002  Balam A. Willemsen, J. S. Derov and S.Sridhar ...
# 2468401  supr-con/9609003  Yasumasa Hasegawa (Himeji Institute of Technol...
# 2468402  supr-con/9609004  Naoki Enomoto, Masanori Ichioka and Kazushige ...
#
#                                                      title  \
# 0        Calculation of prompt diphoton production cros...
# 1                 Sparsity-certifying Graph Decompositions
# 1                 Sparsity-certifying Graph Decompositions
# 2        The evolution of the Earth-Moon system based o...
# 3        A determinant of Stirling cycle numbers counts...
# ...                                                    ...
# 2468398  On the origin of the irreversibility line in t...
# 2468399  Nonlinear Response of HTSC Thin Film Microwave...
# 2468400  Critical State Flux Penetration and Linear Mic...
# 2468401  Density of States and NMR Relaxation Rate in A...
# 2468402  Ginzburg Landau theory for d-wave pairing and ...
#
#                          categories  \
# 0                            hep-ph
# 1                     math.CO cs.CG
# 1                     math.CO cs.CG
# 2                    physics.gen-ph
# 3                           math.CO
# ...                             ...
# 2468398  supr-con cond-mat.supr-con
# 2468399  supr-con cond-mat.supr-con
# 2468400  supr-con cond-mat.supr-con
# 2468401  supr-con cond-mat.supr-con
# 2468402  supr-con cond-mat.supr-con
#
#                                                   abstract  \
# 0          A fully differential calculation in perturba...
# 1          We describe a new algorithm, the $(k,\ell)$-...
# 1          We describe a new algorithm, the $(k,\ell)$-...
# 2          The evolution of Earth-Moon system is descri...
# 3          We show that a determinant of Stirling cycle...
# ...                                                    ...
# 2468398    We report on measurements of the angular dep...
# 2468399    The non-linear microwave surface impedance o...
# 2468400    The vortex contribution to the dc field (H) ...
# 2468401    We show that the density of states in an ani...
# 2468402    The Ginzburg Landau theory for d_{x^2-y^2}-w...
#
#                                                   versions update_date  \
# 0        [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2008-11-26
# 1        [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2008-12-13
# 1        [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2008-12-13
# 2        [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...  2008-01-13
# 3        [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2007-05-23
# ...                                                    ...         ...
# 2468398  [{'version': 'v1', 'created': 'Mon, 26 Aug 199...  2009-10-30
# 2468399  [{'version': 'v1', 'created': 'Sat, 31 Aug 199...  2016-11-18
# 2468400  [{'version': 'v1', 'created': 'Tue, 3 Sep 1996...  2009-10-30
# 2468401  [{'version': 'v1', 'created': 'Wed, 18 Sep 199...  2009-10-30
# 2468402  [{'version': 'v1', 'created': 'Wed, 25 Sep 199...  2009-10-30
#
#                                             authors_parsed  num_authors  year  \
# 0        [[Balázs, C., ], [Berger, E. L., ], [Nadolsky,...            4  2008
# 1                 [[Streinu, Ileana, ], [Theran, Louis, ]]            2  2008
# 1                 [[Streinu, Ileana, ], [Theran, Louis, ]]            2  2008
# 2                                       [[Pan, Hongjun, ]]            1  2008
# 3                                      [[Callan, David, ]]            1  2007
# ...                                                    ...          ...   ...
# 2468398  [[Prozorov, R., ], [Konczykowski, M., ], [Schm...            7  2009
# 2468399  [[Choudhury, Durga P., , Physics Department, N...            4  2016
# 2468400  [[Willemsen, Balam A., , Physics Department,\n...            3  2009
# 2468401  [[Hasegawa, Yasumasa, , Himeji Institute of Te...            1  2009
# 2468402  [[Enomoto, Naoki, , Okayama Univ.], [Ichioka, ...            3  2009
#
#          num_versions     sep_categories                             category
# 0                   2             hep-ph  High Energy Physics - Phenomenology
# 1                   2            math.CO                        Combinatorics
# 1                   2              cs.CG               Computational Geometry
# 2                   3     physics.gen-ph                      General Physics
# 3                   1            math.CO                        Combinatorics
# ...               ...                ...                                  ...
# 2468398             1  cond-mat.supr-con                    Superconductivity
# 2468399             1  cond-mat.supr-con                    Superconductivity
# 2468400             1  cond-mat.supr-con                    Superconductivity
# 2468401             1  cond-mat.supr-con                    Superconductivity
# 2468402             1  cond-mat.supr-con                    Superconductivity
#
# [3845208 rows x 13 columns]

# %%
# Calculate the number of topics for each publication
arxiv_df['count_topics'] = arxiv_df['categories'].apply(lambda x: len(x.split()))
arxiv_df
# Out:
# /tmp/ipykernel_18/1296202861.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   arxiv_df['count_topics'] = arxiv_df['categories'].apply(lambda x: len(x.split()))
#                        id                                            authors  \
# 0               0704.0001  C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1               0704.0002                    Ileana Streinu and Louis Theran
# 2               0704.0003                                        Hongjun Pan
# 3               0704.0004                                       David Callan
# 4               0704.0005           Wael Abu-Shammala and Alberto Torchinsky
# ...                   ...                                                ...
# 2468398  supr-con/9608008  R. Prozorov, M. Konczykowski, B. Schmidt, Y. Y...
# 2468399  supr-con/9609001  Durga P. Choudhury, Balam A. Willemsen, John S...
# 2468400  supr-con/9609002  Balam A. Willemsen, J. S. Derov and S.Sridhar ...
# 2468401  supr-con/9609003  Yasumasa Hasegawa (Himeji Institute of Technol...
# 2468402  supr-con/9609004  Naoki Enomoto, Masanori Ichioka and Kazushige ...
#
#                                                      title  \
# 0        Calculation of prompt diphoton production cros...
# 1                 Sparsity-certifying Graph Decompositions
# 2        The evolution of the Earth-Moon system based o...
# 3        A determinant of Stirling cycle numbers counts...
# 4        From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
# ...                                                    ...
# 2468398  On the origin of the irreversibility line in t...
# 2468399  Nonlinear Response of HTSC Thin Film Microwave...
# 2468400  Critical State Flux Penetration and Linear Mic...
# 2468401  Density of States and NMR Relaxation Rate in A...
# 2468402  Ginzburg Landau theory for d-wave pairing and ...
#
#                          categories  \
# 0                            hep-ph
# 1                     math.CO cs.CG
# 2                    physics.gen-ph
# 3                           math.CO
# 4                   math.CA math.FA
# ...                             ...
# 2468398  supr-con cond-mat.supr-con
# 2468399  supr-con cond-mat.supr-con
# 2468400  supr-con cond-mat.supr-con
# 2468401  supr-con cond-mat.supr-con
# 2468402  supr-con cond-mat.supr-con
#
#                                                   abstract  \
# 0          A fully differential calculation in perturba...
# 1          We describe a new algorithm, the $(k,\ell)$-...
# 2          The evolution of Earth-Moon system is descri...
# 3          We show that a determinant of Stirling cycle...
# 4          In this paper we show how to compute the $\L...
# ...                                                    ...
# 2468398    We report on measurements of the angular dep...
# 2468399    The non-linear microwave surface impedance o...
# 2468400    The vortex contribution to the dc field (H) ...
# 2468401    We show that the density of states in an ani...
# 2468402    The Ginzburg Landau theory for d_{x^2-y^2}-w...
#
#                                                   versions update_date  \
# 0        [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2008-11-26
# 1        [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2008-12-13
# 2        [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...  2008-01-13
# 3        [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2007-05-23
# 4        [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2013-10-15
# ...                                                    ...         ...
# 2468398  [{'version': 'v1', 'created': 'Mon, 26 Aug 199...  2009-10-30
# 2468399  [{'version': 'v1', 'created': 'Sat, 31 Aug 199...  2016-11-18
# 2468400  [{'version': 'v1', 'created': 'Tue, 3 Sep 1996...  2009-10-30
# 2468401  [{'version': 'v1', 'created': 'Wed, 18 Sep 199...  2009-10-30
# 2468402  [{'version': 'v1', 'created': 'Wed, 25 Sep 199...  2009-10-30
#
#                                             authors_parsed  num_authors  year  \
# 0        [[Balázs, C., ], [Berger, E. L., ], [Nadolsky,...            4  2008
# 1                 [[Streinu, Ileana, ], [Theran, Louis, ]]            2  2008
# 2                                       [[Pan, Hongjun, ]]            1  2008
# 3                                      [[Callan, David, ]]            1  2007
# 4        [[Abu-Shammala, Wael, ], [Torchinsky, Alberto, ]]            2  2013
# ...                                                    ...          ...   ...
# 2468398  [[Prozorov, R., ], [Konczykowski, M., ], [Schm...            7  2009
# 2468399  [[Choudhury, Durga P., , Physics Department, N...            4  2016
# 2468400  [[Willemsen, Balam A., , Physics Department,\n...            3  2009
# 2468401  [[Hasegawa, Yasumasa, , Himeji Institute of Te...            1  2009
# 2468402  [[Enomoto, Naoki, , Okayama Univ.], [Ichioka, ...            3  2009
#
#          num_versions                 sep_categories  count_topics
# 0                   2                       [hep-ph]             1
# 1                   2               [math.CO, cs.CG]             2
# 2                   3               [physics.gen-ph]             1
# 3                   1                      [math.CO]             1
# 4                   1             [math.CA, math.FA]             2
# ...               ...                            ...           ...
# 2468398             1  [supr-con, cond-mat.supr-con]             2
# 2468399             1  [supr-con, cond-mat.supr-con]             2
# 2468400             1  [supr-con, cond-mat.supr-con]             2
# 2468401             1  [supr-con, cond-mat.supr-con]             2
# 2468402             1  [supr-con, cond-mat.supr-con]             2
#
# [2352186 rows x 13 columns]

# %% [markdown]
# # Show the average categories count chart by year

# %%
average_topic_count_by_year = arxiv_df.groupby('year')['count_topics'].mean().reset_index()

# Plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='year', y='count_topics', data=average_topic_count_by_year, color='skyblue',zorder=0)
plt.title('Average categories count by year')
plt.xlabel('Year')
plt.ylabel('Average categories count')
plt.xticks(rotation=45)
plt.grid(axis='y')  # Add gridlines on y-axis
plt.tight_layout()
plt.savefig('average_categories_count_by_year.png')
plt.show()

# %%
# show the results
print(average_topic_count_by_year)
# Out:
#     year  count_topics
# 0   2007      1.469020
# 1   2008      1.583397
# 2   2009      1.422354
# 3   2010      1.593820
# 4   2011      1.657567
# 5   2012      1.705893
# 6   2013      1.690022
# 7   2014      1.648626
# 8   2015      1.598216
# 9   2016      1.632111
# 10  2017      1.622594
# 11  2018      1.653423
# 12  2019      1.751860
# 13  2020      1.867815
# 14  2021      1.849930
# 15  2022      1.867166
# 16  2023      1.880986

# %%
# Create a new column 'top_category' by applying a lambda function to each element in the 'sep_categories' column.
# The lambda function maps each category code to its corresponding top-level category using the 'category_dict' dictionary.
df_exploded['top_category'] = df_exploded['sep_categories'].apply(lambda x: category_dict[x])
df_exploded
# Out:
#                        id                                            authors  \
# 0               0704.0001  C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1               0704.0002                    Ileana Streinu and Louis Theran
# 1               0704.0002                    Ileana Streinu and Louis Theran
# 2               0704.0003                                        Hongjun Pan
# 3               0704.0004                                       David Callan
# ...                   ...                                                ...
# 2468398  supr-con/9608008  R. Prozorov, M. Konczykowski, B. Schmidt, Y. Y...
# 2468399  supr-con/9609001  Durga P. Choudhury, Balam A. Willemsen, John S...
# 2468400  supr-con/9609002  Balam A. Willemsen, J. S. Derov and S.Sridhar ...
# 2468401  supr-con/9609003  Yasumasa Hasegawa (Himeji Institute of Technol...
# 2468402  supr-con/9609004  Naoki Enomoto, Masanori Ichioka and Kazushige ...
#
#                                                      title  \
# 0        Calculation of prompt diphoton production cros...
# 1                 Sparsity-certifying Graph Decompositions
# 1                 Sparsity-certifying Graph Decompositions
# 2        The evolution of the Earth-Moon system based o...
# 3        A determinant of Stirling cycle numbers counts...
# ...                                                    ...
# 2468398  On the origin of the irreversibility line in t...
# 2468399  Nonlinear Response of HTSC Thin Film Microwave...
# 2468400  Critical State Flux Penetration and Linear Mic...
# 2468401  Density of States and NMR Relaxation Rate in A...
# 2468402  Ginzburg Landau theory for d-wave pairing and ...
#
#                          categories  \
# 0                            hep-ph
# 1                     math.CO cs.CG
# 1                     math.CO cs.CG
# 2                    physics.gen-ph
# 3                           math.CO
# ...                             ...
# 2468398  supr-con cond-mat.supr-con
# 2468399  supr-con cond-mat.supr-con
# 2468400  supr-con cond-mat.supr-con
# 2468401  supr-con cond-mat.supr-con
# 2468402  supr-con cond-mat.supr-con
#
#                                                   abstract  \
# 0          A fully differential calculation in perturba...
# 1          We describe a new algorithm, the $(k,\ell)$-...
# 1          We describe a new algorithm, the $(k,\ell)$-...
# 2          The evolution of Earth-Moon system is descri...
# 3          We show that a determinant of Stirling cycle...
# ...                                                    ...
# 2468398    We report on measurements of the angular dep...
# 2468399    The non-linear microwave surface impedance o...
# 2468400    The vortex contribution to the dc field (H) ...
# 2468401    We show that the density of states in an ani...
# 2468402    The Ginzburg Landau theory for d_{x^2-y^2}-w...
#
#                                                   versions update_date  \
# 0        [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2008-11-26
# 1        [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2008-12-13
# 1        [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2008-12-13
# 2        [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...  2008-01-13
# 3        [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2007-05-23
# ...                                                    ...         ...
# 2468398  [{'version': 'v1', 'created': 'Mon, 26 Aug 199...  2009-10-30
# 2468399  [{'version': 'v1', 'created': 'Sat, 31 Aug 199...  2016-11-18
# 2468400  [{'version': 'v1', 'created': 'Tue, 3 Sep 1996...  2009-10-30
# 2468401  [{'version': 'v1', 'created': 'Wed, 18 Sep 199...  2009-10-30
# 2468402  [{'version': 'v1', 'created': 'Wed, 25 Sep 199...  2009-10-30
#
#                                             authors_parsed  num_authors  year  \
# 0        [[Balázs, C., ], [Berger, E. L., ], [Nadolsky,...            4  2008
# 1                 [[Streinu, Ileana, ], [Theran, Louis, ]]            2  2008
# 1                 [[Streinu, Ileana, ], [Theran, Louis, ]]            2  2008
# 2                                       [[Pan, Hongjun, ]]            1  2008
# 3                                      [[Callan, David, ]]            1  2007
# ...                                                    ...          ...   ...
# 2468398  [[Prozorov, R., ], [Konczykowski, M., ], [Schm...            7  2009
# 2468399  [[Choudhury, Durga P., , Physics Department, N...            4  2016
# 2468400  [[Willemsen, Balam A., , Physics Department,\n...            3  2009
# 2468401  [[Hasegawa, Yasumasa, , Himeji Institute of Te...            1  2009
# 2468402  [[Enomoto, Naoki, , Okayama Univ.], [Ichioka, ...            3  2009
#
#          num_versions     sep_categories                             category  \
# 0                   2             hep-ph  High Energy Physics - Phenomenology
# 1                   2            math.CO                        Combinatorics
# 1                   2              cs.CG               Computational Geometry
# 2                   3     physics.gen-ph                      General Physics
# 3                   1            math.CO                        Combinatorics
# ...               ...                ...                                  ...
# 2468398             1  cond-mat.supr-con                    Superconductivity
# 2468399             1  cond-mat.supr-con                    Superconductivity
# 2468400             1  cond-mat.supr-con                    Superconductivity
# 2468401             1  cond-mat.supr-con                    Superconductivity
# 2468402             1  cond-mat.supr-con                    Superconductivity
#
#              top_category
# 0                 Physics
# 1             Mathematics
# 1        Computer Science
# 2                 Physics
# 3             Mathematics
# ...                   ...
# 2468398           Physics
# 2468399           Physics
# 2468400           Physics
# 2468401           Physics
# 2468402           Physics
#
# [3845208 rows x 14 columns]

# %% [markdown]
# # Show the chart of number of p ublications by category per year

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Group by 'year' and 'category' and count the number of publications
publications_by_category_year = df_exploded.groupby(['year', 'top_category']).size().reset_index(name='count')
publications_by_category_year['year'] = publications_by_category_year['year'].astype(str)

# Plot using Seaborn
sns.set(style="whitegrid")
plt.figure(figsize=(12, 8))
sns.lineplot(x='year', y='count', hue='top_category', data=publications_by_category_year,markers=True, dashes=False,lw=2)
plt.title('Number of publications by category each year')
plt.xlabel('Year')
plt.ylabel('Number of publications')
plt.legend(title='Category', loc='upper left')
plt.xticks(rotation=45)
plt.grid(axis='y')  # Add gridlines on y-axis
plt.tight_layout()
plt.savefig('Number_of_Publications_by_Category_by_Year.png')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
# Filter the relevant columns
connected_cat = df_exploded[['id','category','year']]

connected_cat
# Out:
#                        id                             category  year
# 0               0704.0001  High Energy Physics - Phenomenology  2008
# 1               0704.0002                        Combinatorics  2008
# 1               0704.0002               Computational Geometry  2008
# 2               0704.0003                      General Physics  2008
# 3               0704.0004                        Combinatorics  2007
# ...                   ...                                  ...   ...
# 2468398  supr-con/9608008                    Superconductivity  2009
# 2468399  supr-con/9609001                    Superconductivity  2016
# 2468400  supr-con/9609002                    Superconductivity  2009
# 2468401  supr-con/9609003                    Superconductivity  2009
# 2468402  supr-con/9609004                    Superconductivity  2009
#
# [3845208 rows x 3 columns]

# %% [markdown]
# # Show the top 3 categories each year

# %%
# Group the data by year and category, count the occurrences, and reset index to create a DataFrame with counts
publication_counts = connected_cat.groupby(['year', 'category']).size().reset_index(name='count')

# Sort the DataFrame first by year in ascending order and then by count in descending order
publication_counts_sorted = publication_counts.sort_values(by=['year', 'count'], ascending=[True, False])

# Select the top 3 categories for each year and reset index to create a new DataFrame
top_categories_each_year = publication_counts_sorted.groupby('year').head(3).reset_index()

# Select the top 10 categories for each year and reset index to create another DataFrame
top_10_categories_each_year = publication_counts_sorted.groupby('year').head(10).reset_index()

# Replace any occurrence of " - " with a space in the 'category' column using regular expressions
top_10_categories_each_year['category'].replace(" - ", ' ', regex=True, inplace=True)
top_categories_each_year['category'].replace(" - ", ' ', regex=True, inplace=True)

# Pivot the DataFrame to create a new DataFrame suitable for a stacked bar plot
pivot_df = top_categories_each_year.pivot(index='year', columns='category', values='count')

# Plot the stacked bar plot with specified parameters
pivot_df.plot(kind='bar', stacked=True, colormap='Set3', width=0.8, figsize=(12, 6))
plt.title('Top 3 categories each year')  # Set plot title
plt.xlabel('Year')  # Set x-axis label
plt.ylabel('Number of publications')  # Set y-axis label
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend(title='Legend title', loc='upper left')  # Set legend title and adjust position

plt.tight_layout()  # Adjust layout to prevent overlap of labels
plt.savefig('Top 3 categories each year.png')  # Save the plot as an image
plt.show()  # Display the plot
# Out:
# /tmp/ipykernel_18/2062085535.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   top_10_categories_each_year['category'].replace(" - ", ' ', regex=True, inplace=True)
# /tmp/ipykernel_18/2062085535.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   top_categories_each_year['category'].replace(" - ", ' ', regex=True, inplace=True)

# %%
print(top_categories_each_year)
# Out:
#     index  year                                  category  count
# 0      57  2007         High Energy Physics Phenomenology  14872
# 1      70  2007                      Mathematical Physics  13048
# 2      58  2007                High Energy Physics Theory  11558
# 3     180  2008         High Energy Physics Phenomenology  13642
# 4     181  2008                High Energy Physics Theory  11488
# 5     170  2008  General Relativity and Quantum Cosmology   5704
# 6     314  2009                High Energy Physics Theory  30830
# 7     313  2009         High Energy Physics Phenomenology  30689
# 8     376  2009                     Statistical Mechanics  14444
# 9     450  2010                High Energy Physics Theory   7555
# 10    449  2010         High Energy Physics Phenomenology   7438
# 11    463  2010                      Mathematical Physics   4590
# 12    589  2011         High Energy Physics Phenomenology   8575
# 13    590  2011                High Energy Physics Theory   6632
# 14    603  2011                      Mathematical Physics   6470
# 15    743  2012                      Mathematical Physics   5820
# 16    781  2012                           Quantum Physics   3983
# 17    729  2012         High Energy Physics Phenomenology   3269
# 18    883  2013                      Mathematical Physics   6198
# 19    869  2013         High Energy Physics Phenomenology   5769
# 20    921  2013                           Quantum Physics   5488
# 21   1010  2014         High Energy Physics Phenomenology   9669
# 22   1011  2014                High Energy Physics Theory   7463
# 23   1025  2014                      Mathematical Physics   6652
# 24   1119  2015    Cosmology and Nongalactic Astrophysics  19077
# 25   1167  2015                      Mathematical Physics  18044
# 26   1152  2015         High Energy Physics Phenomenology  17464
# 27   1294  2016         High Energy Physics Phenomenology  10047
# 28   1300  2016                        Information Theory   9976
# 29   1309  2016                      Mathematical Physics   9114
# 30   1455  2017                      Mathematical Physics   8004
# 31   1452  2017                          Machine Learning   7808
# 32   1439  2017         High Energy Physics Phenomenology   7754
# 33   1600  2018                          Machine Learning  15032
# 34   1550  2018   Computer Vision and Pattern Recognition   7709
# 35   1603  2018                      Mathematical Physics   7708
# 36   1749  2019                          Machine Learning  26690
# 37   1699  2019   Computer Vision and Pattern Recognition  10511
# 38   1752  2019                      Mathematical Physics   8044
# 39   1898  2020                          Machine Learning  35261
# 40   1848  2020   Computer Vision and Pattern Recognition  14365
# 41   1901  2020                      Mathematical Physics   9146
# 42   2047  2021                          Machine Learning  33828
# 43   1997  2021   Computer Vision and Pattern Recognition  16881
# 44   1971  2021                   Artificial Intelligence  11370
# 45   2196  2022                          Machine Learning  35224
# 46   2146  2022   Computer Vision and Pattern Recognition  19629
# 47   2120  2022                   Artificial Intelligence  14352
# 48   2345  2023                          Machine Learning  44235
# 49   2295  2023   Computer Vision and Pattern Recognition  26035
# 50   2269  2023                   Artificial Intelligence  22602

# %%
# show the top 10 categories each year
top_10_categories_each_year
# Out:
#      index  year                           category  count
# 0       57  2007  High Energy Physics Phenomenology  14872
# 1       70  2007               Mathematical Physics  13048
# 2       58  2007         High Energy Physics Theory  11558
# 3      104  2007                    Quantum Physics  10485
# 4        2  2007                 Algebraic Geometry   7006
# ..     ...   ...                                ...    ...
# 165   2348  2023               Mathematical Physics  13216
# 166   2407  2023                Systems and Control  11949
# 167   2363  2023                 Numerical Analysis  11155
# 168   2333  2023         High Energy Physics Theory   9614
# 169   2332  2023  High Energy Physics Phenomenology   9454
#
# [170 rows x 4 columns]

# %%
# !pip install -U kaleido
# !pip install fiftyone -y

# %%
# !pip install plotly
# !conda install -c conda-forge python-kaleido -y
# Out:
# Requirement already satisfied: plotly in /opt/conda/lib/python3.10/site-packages (5.18.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from plotly) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->plotly) (3.1.1)
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
#  - rapidsai
#  - nvidia
#  - defaults
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.4.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - python-kaleido
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     kaleido-core-0.2.1         |       h3644ca4_0        59.2 MB  conda-forge
#     mathjax-2.7.7              |       ha770c72_3        21.2 MB  conda-forge
#     nspr-4.35                  |       h27087fc_0         222 KB  conda-forge
#     nss-3.97                   |       h1d7d5a4_0         1.9 MB  conda-forge
#     openssl-3.3.0              |       hd590300_0         2.8 MB  conda-forge
#     python-kaleido-0.2.1       |     pyhd8ed1ab_0          18 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        85.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   kaleido-core       conda-forge/linux-64::kaleido-core-0.2.1-h3644ca4_0
#   mathjax            conda-forge/linux-64::mathjax-2.7.7-ha770c72_3
#   nspr               conda-forge/linux-64::nspr-4.35-h27087fc_0
#   nss                conda-forge/linux-64::nss-3.97-h1d7d5a4_0
#   python-kaleido     conda-forge/noarch::python-kaleido-0.2.1-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   openssl                                  3.2.1-hd590300_0 --> 3.3.0-hd590300_0
#
#
#
# Downloading and Extracting Packages:
# kaleido-core-0.2.1   | 59.2 MB   |                                       |   0%
# mathjax-2.7.7        | 21.2 MB   |                                       |   0%
#
# openssl-3.3.0        | 2.8 MB    |                                       |   0%
#
#
# nss-3.97             | 1.9 MB    |                                       |   0%
#
#
#
# nspr-4.35            | 222 KB    |                                       |   0%
#
#
#
#
# python-kaleido-0.2.1 | 18 KB     |                                       |   0%
# kaleido-core-0.2.1   | 59.2 MB   |                                       |   0%
#
#
# nss-3.97             | 1.9 MB    | 3                                     |   1%
#
# openssl-3.3.0        | 2.8 MB    | 2                                     |   1%
#
#
#
# nspr-4.35            | 222 KB    | ##6                                   |   7%
# kaleido-core-0.2.1   | 59.2 MB   | #                                     |   3%
#
#
#
#
# python-kaleido-0.2.1 | 18 KB     | #################################     |  89%
#
# openssl-3.3.0        | 2.8 MB    | #####################7                |  59%
# kaleido-core-0.2.1   | 59.2 MB   | #9                                    |   5%
#
#
#
#
# python-kaleido-0.2.1 | 18 KB     | ##################################### | 100%
# kaleido-core-0.2.1   | 59.2 MB   | ###                                   |   8%
# kaleido-core-0.2.1   | 59.2 MB   | ###9                                  |  11%
#
#
#
# nspr-4.35            | 222 KB    | ##################################### | 100%
#
#
#
# nspr-4.35            | 222 KB    | ##################################### | 100%
# kaleido-core-0.2.1   | 59.2 MB   | #####2                                |  14%
# kaleido-core-0.2.1   | 59.2 MB   | #######1                              |  19%
# kaleido-core-0.2.1   | 59.2 MB   | #########                             |  25%
# kaleido-core-0.2.1   | 59.2 MB   | ##########7                           |  29%
# kaleido-core-0.2.1   | 59.2 MB   | ###############3                      |  41%
#
# openssl-3.3.0        | 2.8 MB    | ##################################### | 100%
#
# openssl-3.3.0        | 2.8 MB    | ##################################### | 100%
#
#
# nss-3.97             | 1.9 MB    | ##################################### | 100%
#
#
# kaleido-core-0.2.1   | 59.2 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %%
# Import necessary libraries for plotting
import plotly.graph_objects as go  # Plotly graph objects
import plotly.io as pio  # Plotly I/O
import plotly.express as px  # Plotly express for easy plotting

# Replace spaces in the 'category' column with '<br>' to enable multiline display in the treemap
top_10_categories_each_year['v_cat'] = top_10_categories_each_year['category'].str.replace(' ', '<br>')

# Create a new Plotly figure object
fig = go.Figure()

# Create a treemap using Plotly express with specified parameters
fig = px.treemap(top_10_categories_each_year,  # DataFrame to use for plotting
                 path=['year', 'v_cat'],  # Define hierarchy of categories
                 values='count',  # Define values for treemap tiles
                 title='Treemap of Categories by Year',  # Set plot title
                 branchvalues='total',  # Specify how values are aggregated
                 width=1600,  # Set width of the plot
                 height=1200  # Set height of the plot
                )

# Update traces of the treemap to include label and value information, and set text and pathbar font sizes
fig.update_traces(textinfo='label+value',  # Display label and value on treemap tiles
                  selector=dict(type='treemap'),  # Select treemap traces
                  textfont_size=12,  # Set text font size
                  pathbar_textfont_size=12  # Set pathbar text font size
                 )

# Display the treemap
fig.show()

# Write the treemap as an image file with specified scale, width, and height
fig.write_image("categories_treemap.png", scale=6, width=1600, height=900)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="21745ba2-52ae-4a44-9c0f-5a8f4a9cc4d4" class="plotly-graph-div" style="height:1200px; width:1600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21745ba2-52ae-4a44-9c0f-5a8f4a9cc4d4")) {                    Plotly.newPlot(                        "21745ba2-52ae-4a44-9c0f-5a8f4a9cc4d4",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["2007\u002fAlgebraic\u003cbr\u003eGeometry","2008\u002fAlgebraic\u003cbr\u003eGeometry","2021\u002fArtificial\u003cbr\u003eIntelligence","2022\u002fArtificial\u003cbr\u003eIntelligence","2023\u002fArtificial\u003cbr\u003eIntelligence","2015\u002fAstrophysics\u003cbr\u003eof\u003cbr\u003eGalaxies","2016\u002fAstrophysics\u003cbr\u003eof\u003cbr\u003eGalaxies","2017\u002fAstrophysics\u003cbr\u003eof\u003cbr\u003eGalaxies","2018\u002fAstrophysics\u003cbr\u003eof\u003cbr\u003eGalaxies","2012\u002fCombinatorics","2014\u002fCombinatorics","2021\u002fComputation\u003cbr\u003eand\u003cbr\u003eLanguage","2022\u002fComputation\u003cbr\u003eand\u003cbr\u003eLanguage","2023\u002fComputation\u003cbr\u003eand\u003cbr\u003eLanguage","2017\u002fComputer\u003cbr\u003eVision\u003cbr\u003eand\u003cbr\u003ePattern\u003cbr\u003eRecognition","2018\u002fComputer\u003cbr\u003eVision\u003cbr\u003eand\u003cbr\u003ePattern\u003cbr\u003eRecognition","2019\u002fComputer\u003cbr\u003eVision\u003cbr\u003eand\u003cbr\u003ePattern\u003cbr\u003eRecognition","2020\u002fComputer\u003cbr\u003eVision\u003cbr\u003eand\u003cbr\u003ePattern\u003cbr\u003eRecognition","2021\u002fComputer\u003cbr\u003eVision\u003cbr\u003eand\u003cbr\u003ePattern\u003cbr\u003eRecognition","2022\u002fComputer\u003cbr\u003eVision\u003cbr\u003eand\u003cbr\u003ePattern\u003cbr\u003eRecognition","2023\u002fComputer\u003cbr\u003eVision\u003cbr\u003eand\u003cbr\u003ePattern\u003cbr\u003eRecognition","2010\u002fCosmology\u003cbr\u003eand\u003cbr\u003eNongalactic\u003cbr\u003eAstrophysics","2011\u002fCosmology\u003cbr\u003eand\u003cbr\u003eNongalactic\u003cbr\u003eAstrophysics","2013\u002fCosmology\u003cbr\u003eand\u003cbr\u003eNongalactic\u003cbr\u003eAstrophysics","2014\u002fCosmology\u003cbr\u003eand\u003cbr\u003eNongalactic\u003cbr\u003eAstrophysics","2015\u002fCosmology\u003cbr\u003eand\u003cbr\u003eNongalactic\u003cbr\u003eAstrophysics","2007\u002fDifferential\u003cbr\u003eGeometry","2007\u002fGeneral\u003cbr\u003eRelativity\u003cbr\u003eand\u003cbr\u003eQuantum\u003cbr\u003eCosmology","2008\u002fGeneral\u003cbr\u003eRelativity\u003cbr\u003eand\u003cbr\u003eQuantum\u003cbr\u003eCosmology","2009\u002fGeneral\u003cbr\u003eRelativity\u003cbr\u003eand\u003cbr\u003eQuantum\u003cbr\u003eCosmology","2010\u002fGeneral\u003cbr\u003eRelativity\u003cbr\u003eand\u003cbr\u003eQuantum\u003cbr\u003eCosmology","2011\u002fGeneral\u003cbr\u003eRelativity\u003cbr\u003eand\u003cbr\u003eQuantum\u003cbr\u003eCosmology","2012\u002fGeneral\u003cbr\u003eRelativity\u003cbr\u003eand\u003cbr\u003eQuantum\u003cbr\u003eCosmology","2013\u002fGeneral\u003cbr\u003eRelativity\u003cbr\u003eand\u003cbr\u003eQuantum\u003cbr\u003eCosmology","2014\u002fGeneral\u003cbr\u003eRelativity\u003cbr\u003eand\u003cbr\u003eQuantum\u003cbr\u003eCosmology","2015\u002fGeneral\u003cbr\u003eRelativity\u003cbr\u003eand\u003cbr\u003eQuantum\u003cbr\u003eCosmology","2016\u002fGeneral\u003cbr\u003eRelativity\u003cbr\u003eand\u003cbr\u003eQuantum\u003cbr\u003eCosmology","2017\u002fGeneral\u003cbr\u003eRelativity\u003cbr\u003eand\u003cbr\u003eQuantum\u003cbr\u003eCosmology","2018\u002fGeneral\u003cbr\u003eRelativity\u003cbr\u003eand\u003cbr\u003eQuantum\u003cbr\u003eCosmology","2015\u002fHigh\u003cbr\u003e ...

# %%
# show connected categories dataframe
connected_cat
# Out:
#                        id                             category  year
# 0               0704.0001  High Energy Physics - Phenomenology  2008
# 1               0704.0002                        Combinatorics  2008
# 1               0704.0002               Computational Geometry  2008
# 2               0704.0003                      General Physics  2008
# 3               0704.0004                        Combinatorics  2007
# ...                   ...                                  ...   ...
# 2468398  supr-con/9608008                    Superconductivity  2009
# 2468399  supr-con/9609001                    Superconductivity  2016
# 2468400  supr-con/9609002                    Superconductivity  2009
# 2468401  supr-con/9609003                    Superconductivity  2009
# 2468402  supr-con/9609004                    Superconductivity  2009
#
# [3845208 rows x 3 columns]

# %% [markdown]
# # Show the most common category each year

# %%
# Group the DataFrame by 'year' and find the most common category for each year
most_common_category = connected_cat.groupby('year')['category'].agg(lambda x: x.mode()[0]).reset_index()

# Display the DataFrame showing the most common category for each year
most_common_category

# Plot using Seaborn
plt.figure(figsize=(10, 6))  # Set the size of the plot
sns.barplot(x='year', y='category', data=most_common_category, palette='viridis')  # Create a bar plot using Seaborn
plt.title('Most Common Category Each Year')  # Set the title of the plot
plt.xlabel('Year')  # Set the label for the x-axis
plt.ylabel('Category')  # Set the label for the y-axis
plt.xticks(rotation=45)  # Rotate the x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent overlapping elements
plt.show()  # Display the plot

# %%
# Prepare dataframe for connection graph
network_connected_cat = connected_cat.groupby('id')

# %% [markdown]
# # Show the top 40 Connected Categories

# %%
# Import necessary libraries
import networkx as nx
import plotly.graph_objects as go
from itertools import combinations

# Create an empty graph
G = nx.Graph()

# Iterate over each group in the grouped DataFrame
for idx in list(network_connected_cat.groups.keys()):
    # Get the length of the group
    cat_len = len(network_connected_cat.get_group(idx))
    # Check if the group has more than one category
    if cat_len > 1:
        # Generate pairs of combinations of categories within the group
        pairs = list(combinations(list(range(0, cat_len)), 2))
        # Add edges to the graph for each pair of categories
        for pair in pairs:
            category1 = network_connected_cat.get_group(idx).iloc[pair[0]].category
            category2 = network_connected_cat.get_group(idx).iloc[pair[1]].category
            G.add_edge(category1, category2)

# Calculate betweenness centrality for each node
node_betweenness = nx.betweenness_centrality(G)

# Sort nodes based on betweenness centrality and select the top 40
top_nodes = sorted(G.nodes(), key=lambda x: node_betweenness[x], reverse=True)[:40]

# Filter edges to include only those connected to the top nodes
filtered_edges = [(source, target) for source, target in G.edges() if source in top_nodes or target in top_nodes]

# Create a subgraph containing only the top nodes and their connected edges
G_sub = G.subgraph(top_nodes)

# Create positions for the nodes using a spring layout algorithm with a higher k value for a more sparse layout
pos_sub = nx.spring_layout(G_sub, k=2)

# Create edge trace for the filtered edges
edge_x = []
edge_y = []
for edge in G_sub.edges():
    x0, y0 = pos_sub[edge[0]]
    x1, y1 = pos_sub[edge[1]]
    edge_x.extend([x0, x1, None])
    edge_y.extend([y0, y1, None])

# Create node trace for the top nodes
node_x = []
node_y = []
node_text = []
node_size = []
for node in G_sub.nodes():
    x, y = pos_sub[node]
    node_x.append(x)
    node_y.append(y)
    node_text.append(node)
    node_size.append(node_betweenness[node])

# Define the scaling factor and adjust the size range for nodes
scaling_factor = 10000
min_size = 3
max_size = 100

# Scale the node sizes based on the betweenness centrality
scaled_node_size = [min_size + (s * scaling_factor) for s in node_size]
scaled_node_size = [min(s, max_size) for s in scaled_node_size]

# Create edge trace
edge_trace = go.Scatter(
    x=edge_x,
    y=edge_y,
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines'
)

# Create node trace
node_trace = go.Scatter(
    x=node_x,
    y=node_y,
    text=node_text,
    mode='markers+text',
    hoverinfo='none',
    marker=dict(
        color='#CB1111',
        size=scaled_node_size,
        line=dict(width=2)
    )
)

# Create figure
fig = go.Figure(
    data=[edge_trace, node_trace],
    layout=go.Layout(
        title='Top 40 Connected Categories',
        titlefont=dict(size=8),
        showlegend=False,
        hovermode='closest',
        margin=dict(b=20, l=5, r=5, t=40),
        xaxis=dict(showgrid=False, zeroline=False, showticklabels=True),
        yaxis=dict(showgrid=False, zeroline=False, showticklabels=True)
    )
)

# Show the figure
plt.show()

# %%
# Save to image file
pio.write_image(fig, 'top_40_connected_categories.png',width=1100, height=700, scale=6)

# %% [markdown]
# # Show the top 10 Categoires of betweenness centrality

# %%
# Sort nodes based on betweenness centrality values
sorted_nodes = sorted(node_betweenness.items(), key=lambda x: x[1], reverse=True)

# Select top 10 nodes
top_10_nodes = sorted_nodes[:10]

# Extract node labels and betweenness centrality values
node_labels = [node[0] for node in top_10_nodes]
centrality_values = [node[1] for node in top_10_nodes]

# Plot bar graph
plt.figure(figsize=(10, 6))
plt.bar(node_labels, centrality_values, color='lightblue')
plt.title('Top 10 Categoires of Betweenness Centrality')
plt.xlabel('Category')
plt.ylabel('Betweenness Centrality')
plt.xticks(rotation=45)
plt.tight_layout()

# Save the figure
plt.savefig('top_10_nodes_betweenness_centrality.png')

# Show the figure
plt.show()

# %%
# Installing topic modeling packages
# !pip install BERTopic
# !pip install nltk
# Out:
# Collecting BERTopic
#   Downloading bertopic-0.16.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: numpy>=1.20.0 in /opt/conda/lib/python3.10/site-packages (from BERTopic) (1.26.4)
# Collecting hdbscan>=0.8.29 (from BERTopic)
#   Downloading hdbscan-0.8.33.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 51.9 MB/s eta 0:00:00
# done
# done
# done
# Requirement already satisfied: umap-learn>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from BERTopic) (0.5.5)
# Requirement already satisfied: pandas>=1.1.5 in /opt/conda/lib/python3.10/site-packages (from BERTopic) (2.2.0)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /opt/conda/lib/python3.10/site-packages (from BERTopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /opt/conda/lib/python3.10/site-packages (from BERTopic) (4.66.1)
# Collecting sentence-transformers>=0.4.1 (from BERTopic)
#   Downloading sentence_transformers-2.7.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: plotly>=4.7.0 in /opt/conda/lib/python3.10/site-packages (from BERTopic) (5.18.0)
# Collecting cython<3,>=0.27 (from hdbscan>=0.8.29->BERTopic)
#   Using cached Cython-0.29.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (3.1 kB)
# Requirement already satisfied: scipy>=1.0 in /opt/conda/lib/python3.10/site-packages (from hdbscan>=0.8.29->BERTopic) (1.11.4)
# Requirement already satisfied: joblib>=1.0 in /opt/conda/lib/python3.10/site-packages (from hdbscan>=0.8.29->BERTopic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.5->BERTopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.5->BERTopic) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.5->BERTopic) (2023.4)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from plotly>=4.7.0->BERTopic) (8.2.3)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from plotly>=4.7.0->BERTopic) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.22.2.post1->BERTopic) (3.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers>=0.4.1->BERTopic) (4.38.1)
# Requirement already satisfied: torch>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers>=0.4.1->BERTopic) (2.1.2+cpu)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers>=0.4.1->BERTopic) (0.20.3)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from sentence-transformers>=0.4.1->BERTopic) (9.5.0)
# Requirement already satisfied: numba>=0.51.2 in /opt/conda/lib/python3.10/site-packages (from umap-learn>=0.5.0->BERTopic) (0.58.1)
# Requirement already satisfied: pynndescent>=0.5 in /opt/conda/lib/python3.10/site-packages (from umap-learn>=0.5.0->BERTopic) (0.5.11)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->BERTopic) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->BERTopic) (2024.2.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->BERTopic) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->BERTopic) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->BERTopic) (4.9.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba>=0.51.2->umap-learn>=0.5.0->BERTopic) (0.41.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->plotly>=4.7.0->BERTopic) (3.1.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->BERTopic) (1.16.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->BERTopic) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->BERTopic) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->BERTopic) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.4.1->BERTopic) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.4.1->BERTopic) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.4.1->BERTopic) (0.4.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->BERTopic) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->BERTopic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->BERTopic) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->BERTopic) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->BERTopic) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence-transformers>=0.4.1->BERTopic) (1.3.0)
# Downloading bertopic-0.16.1-py2.py3-none-any.whl (158 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.5/158.5 kB 7.2 MB/s eta 0:00:00
# Downloading sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 7.6 MB/s eta 0:00:00
# Using cached Cython-0.29.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Building wheels for collected packages: hdbscan
# done
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=819466 sha256=46bf6785d7030ea887909d7fdec2ad5dba5a51ed8af2f76f2ae998b7b64057ec
#   Stored in directory: /root/.cache/pip/wheels/75/0b/3b/dc4f60b7cc455efaefb62883a7483e76f09d06ca81cf87d610
# Successfully built hdbscan
# Installing collected packages: cython, hdbscan, sentence-transformers, BERTopic
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.8
#     Uninstalling Cython-3.0.8:
#       Successfully uninstalled Cython-3.0.8
# Successfully installed BERTopic-0.16.1 cython-0.29.37 hdbscan-0.8.33 sentence-transformers-2.7.0
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.2.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from nltk) (1.16.0)

# %%
# Filter the DataFrame to include only rows where the category is 'Machine Learning'
df_exp_cs = df_exploded[df_exploded['category'] == 'Machine Learning']

# Select specific columns from the filtered DataFrame
df_exp_cs = df_exp_cs[['id', 'abstract', 'year', 'category']]

# Print the length of the filtered DataFrame
print(len(df_exp_cs))
# Out:
# 216172

# %%
# show the dataframe of the exploded computer science  
df_exp_cs
# Out:
#                        id                                           abstract  \
# 670             0704.0671    The problem of statistical learning is to co...
# 953             0704.0954    In a sensor network, in practice, the commun...
# 1019            0704.1020    The on-line shortest path problem is conside...
# 1027            0704.1028    Ordinal regression is an important type of l...
# 1138            0704.1139    This paper explores the following question: ...
# ...                   ...                                                ...
# 2444645     q-bio/0401033    One of the major successes in computational ...
# 2444684     q-bio/0402029    Advances in statistical learning theory have...
# 2446093     q-bio/0610040    Much recent work in bioinformatics has focus...
# 2447800  quant-ph/0011122    The probability distribution P from which th...
# 2456789  quant-ph/0411140    In this article we give several new results ...
#
#          year          category
# 670      2016  Machine Learning
# 953      2009  Machine Learning
# 1019     2007  Machine Learning
# 1027     2007  Machine Learning
# 1138     2009  Machine Learning
# ...       ...               ...
# 2444645  2009  Machine Learning
# 2444684  2007  Machine Learning
# 2446093  2007  Machine Learning
# 2447800  2007  Machine Learning
# 2456789  2007  Machine Learning
#
# [216172 rows x 4 columns]

# %% [markdown]
# Prepare the data for topic modeling

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from bertopic import BERTopic
import vaex

# Download NLTK resources
nltk.download('punkt')
nltk.download('stopwords')

# Tokenize the abstracts and remove stop words using NLTK
stop_words = set(stopwords.words('english'))

# Prepare and clean the text before processing
def preprocess_text(text):
    tokens = word_tokenize(text.lower())
    tokens = [token for token in tokens if token.isalpha()]
    tokens = [token for token in tokens if token not in stop_words]
    return ' '.join(tokens)

# Apply preprocessing to the abstract column and convert to veax df
vaex_arxiv_df = vaex.from_pandas(df_exp_cs)
vaex_arxiv_df['cleaned_abstract'] = vaex_arxiv_df['abstract'].apply(preprocess_text)
# Out:
# 2024-04-30 18:48:36.749424: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 18:48:36.749634: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 18:48:36.927825: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Convert the cleaned abstracts to a list
abstracts_list = vaex_arxiv_df['cleaned_abstract'].tolist()
# Out:
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning:
#
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from collections import Counter
import matplotlib.pyplot as plt

# Vectorize the text data
vectorizer = CountVectorizer(max_features=1000, stop_words='english')
X = vectorizer.fit_transform(abstracts_list)

# Apply online LDA
num_topics = 10  
batch_size = 1000  
lda_model = LatentDirichletAllocation(n_components=num_topics, learning_method='online', random_state=42, batch_size=batch_size)
lda_model.fit(X)

# Get the most common words for each topic
topic_words = []
feature_names = vectorizer.get_feature_names_out()
for topic_idx, topic in enumerate(lda_model.components_):
    top_words_idx = topic.argsort()[:-11:-1]
    topic_words.append([feature_names[i] for i in top_words_idx])

# %% [markdown]
# # Show the top common words across all topics in machine learning

# %%
import numpy as np
import matplotlib.pyplot as plt

# Flatten the list of top words for all topics
all_topic_words = [word for topic in topic_words for word in topic]

# Count the frequency of each word
word_counts = Counter(all_topic_words)

# Sort the words by frequency
sorted_words = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)

# Extract the top 20 words and their frequencies
top_words = [word[0] for word in sorted_words[:20]]
word_frequencies = [word[1] for word in sorted_words[:20]]

# Plot the horizontal bar chart
plt.figure(figsize=(10, 8))
plt.barh(top_words, word_frequencies, color='skyblue')
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.title('Top common words across all topics in machine learning')
plt.gca().invert_yaxis()  # Invert y-axis to display the most frequent words at the top
plt.savefig('Most_common_topics_in_Machine_Learing.png')
plt.show()

# %%
from bertopic import BERTopic
import random

# Random the list
random.shuffle(abstracts_list)

# Select a random subset of 10,000 items
subset_abstracts_list = random.sample(abstracts_list, 10000)

# Initialize and fit the BERTopic model with the subset
topic_model = BERTopic(verbose=True, embedding_model="paraphrase-MiniLM-L12-v2", min_topic_size=50)
topics, _ = topic_model.fit_transform(subset_abstracts_list)

# Get information about the topics
topic_info = topic_model.get_topic_info()
print(len(topic_info))  # Check the number of topics
# Out:
# 2024-04-30 19:16:19,867 - BERTopic - Embedding - Transforming documents to embeddings.
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/631 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/313 [00:00<?, ?it/s]
# 2024-04-30 19:28:15,060 - BERTopic - Embedding - Completed ✓
# 2024-04-30 19:28:15,065 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-04-30 19:29:08,956 - BERTopic - Dimensionality - Completed ✓
# 2024-04-30 19:29:08,959 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-04-30 19:29:10,001 - BERTopic - Cluster - Completed ✓
# 2024-04-30 19:29:10,047 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-04-30 19:29:12,829 - BERTopic - Representation - Completed ✓
# 33

# %% [markdown]
# # Show the topic chart info

# %%
# Show first 10 topics words
topic_model.get_topic_info().head(10)
# Out:
#    Topic  Count                                        Name  \
# 0     -1   4156               -1_data_learning_model_models
# 1      0    715          0_policy_reinforcement_rl_learning
# 2      1    568      1_segmentation_medical_clinical_images
# 3      2    334  2_adversarial_attacks_attack_perturbations
# 4      3    331                   3_graph_graphs_node_nodes
# 5      4    296       4_gradient_sgd_stochastic_convergence
# 6      5    290                 5_language_word_text_models
# 7      6    249                6_speech_audio_music_speaker
# 8      7    226                 7_privacy_federated_fl_data
# 9      8    223             8_regret_bandit_algorithm_bound
#
#                                       Representation  \
# 0  [data, learning, model, models, performance, t...
# 1  [policy, reinforcement, rl, learning, reward, ...
# 2  [segmentation, medical, clinical, images, data...
# 3  [adversarial, attacks, attack, perturbations, ...
# 4  [graph, graphs, node, nodes, networks, gnns, n...
# 5  [gradient, sgd, stochastic, convergence, optim...
# 6  [language, word, text, models, model, words, e...
# 7  [speech, audio, music, speaker, asr, acoustic,...
# 8  [privacy, federated, fl, data, learning, clien...
# 9  [regret, bandit, algorithm, bound, arms, arm, ...
#
#                                  Representative_Docs
# 0  [learning models using gaussian processes gp d...
# 1  [recent reinforcement learning rl approaches s...
# 2  [disease progression simulation crucial area r...
# 3  [adversarial examples shown exist variety deep...
# 4  [graph neural networks attracted wide attentio...
# 5  [many machine learning tasks formulated regula...
# 6  [language models essential natural language pr...
# 7  [paper proposes new architecture speaker adapt...
# 8  [federated learning fl machine learning paradi...
# 9  [consider adversarial multi armed bandits mab ...

# %%
# Get the top 10 topic information
topic_info = topic_model.get_topic_info().head(10)  

# Save the topic information to a CSV file
topic_info.to_csv("topic_info.csv", index=False)

# %%
# Visualize the topics bar chart
topic_model.visualize_barchart(top_n_topics=11)
# Out:
# <div>                            <div id="3ced9b3e-aa2d-4912-abd7-82236ca6bcb3" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ced9b3e-aa2d-4912-abd7-82236ca6bcb3")) {                    Plotly.newPlot(                        "3ced9b3e-aa2d-4912-abd7-82236ca6bcb3",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.021541129426095235,0.027579073996031926,0.032150455748517964,0.03376376332802032,0.03468209122135021],"y":["reward  ","learning  ","rl  ","reinforcement  ","policy  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.017382067724992144,0.017957374519631406,0.018050639299958118,0.020061330915824575,0.022142245350989586],"y":["data  ","images  ","clinical  ","medical  ","segmentation  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.022203972224555807,0.024053697427639912,0.03292931935951665,0.04811629121671303,0.07037468714549608],"y":["robustness  ","perturbations  ","attack  ","attacks  ","adversarial  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.025616600865941093,0.027949415222575054,0.03785936480565683,0.04736603438457267,0.08450004932860547],"y":["networks  ","nodes  ","node  ","graphs  ","graph  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.036835203280082184,0.03754665001536218,0.039808912019001864,0.042116151232770946,0.04530248627108122],"y":["optimization  ","convergence  ","stochastic  ","sgd  ","gradient  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.02033208487984701,0.024017230123251448,0.026351985852851166,0.030624688135209365,0.042295425018158445],"y":["model  ","models  ","text  ","word  ","language  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.023550857458920965,0.032613513217724155,0.03391289485178008,0.03945480104900116,0.05805475679038816],"y":["asr  ","speaker  ","music  ","audio  ","speech  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.030511048575244896,0.035445714839894005,0.05071386438514182,0.059364423565881695,0.0652332414607571],"y":["learning  ","data  ","fl  ","federated  ","privacy  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.029133368651044905,0.03640310044329595,0.03992505891078617,0.0517271109030884,0.09506629262581051],"y":["arms  ","bound  ","algorithm  ","bandit  ","regret  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.01843180183629388,0.018614620586367044,0.02020327796455409,0.02395429770466785,0.035783135528364735],"y":["time  ","model  ","series  ","energy  ","forecasting  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.024728031592894648,0.02742417920339803,0.03156660914504779,0.039181967623429924,0.043611856355820516],"y":["data  ","adaptation  ","label  ","labels  ","domain  "],"type":"bar","xaxis":"x11","yaxis":"y11"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3" ...

# %%
# Assuming topic_model is already initialized and fitted
barchart = topic_model.visualize_barchart(top_n_topics=11)

# Save the visualization as an image file
barchart.write_image("topic_barchart.png", width=1920, height=1080)

# %%
# Visualize the the inertopics chart
topic_model.visualize_topics()
# Out:
# <div>                            <div id="32a11eb0-b7ac-49e2-929b-0b704d78249c" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32a11eb0-b7ac-49e2-929b-0b704d78249c")) {                    Plotly.newPlot(                        "32a11eb0-b7ac-49e2-929b-0b704d78249c",                        [{"customdata":[[0,"policy | reinforcement | rl | learning | reward",715],[1,"segmentation | medical | clinical | images | data",568],[2,"adversarial | attacks | attack | perturbations | robustness",334],[3,"graph | graphs | node | nodes | networks",331],[4,"gradient | sgd | stochastic | convergence | optimization",296],[5,"language | word | text | models | model",290],[6,"speech | audio | music | speaker | asr",249],[7,"privacy | federated | fl | data | learning",226],[8,"regret | bandit | algorithm | bound | arms",223],[9,"forecasting | energy | series | model | time",212],[10,"domain | labels | label | adaptation | data",210],[11,"kernel | sparse | matrix | regression | gaussian",197],[12,"image | images | contrastive | video | visual",170],[13,"bayesian | inference | posterior | variational | mcmc",157],[14,"traffic | driving | vehicle | prediction | driver",143],[15,"networks | relu | neural | function | network",139],[16,"equations | differential | pdes | equation | systems",135],[17,"molecular | drug | protein | molecules | chemical",122],[18,"causal | treatment | effect | data | discovery",121],[19,"gans | gan | generative | generator | adversarial",119],[20,"recurrent | rnns | rnn | memory | neural",94],[21,"cnn | cnns | convolutional | layers | layer",94],[22,"user | recommendation | recommender | users | items",88],[23,"explanations | explanation | interpretability | ai | interpretable",87],[24,"deep | learning | neural | network | networks",81],[25,"fairness | fair | sensitive | bias | groups",76],[26,"clustering | clusters | cluster | data | subspace",73],[27,"social | media | sentiment | news | tweets",71],[28,"uncertainty | calibration | quantification | prediction | predictions",58],[29,"bo | optimization | bayesian | acquisition | functions",57],[30,"anomaly | detection | anomalies | data | log",55],[31,"quantization | dnn | weights | weight | pruning",53]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[715,568,334,331,296,290,249,226,223,212,210,197,170,157,143,139,135,122,121,119,94,94,88,87,81,76,73,71,58,57,55,53],"sizemode":"area","sizeref":0.446875,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-10.147216,3.057776,5.152531,3.96031,-1.0551559,15.552608,15.361102,4.339844,-10.178431,-2.1165845,5.1742644,-1.2064123,4.580639,-3.2559752,-2.1165864,16.924297,-1.4058393,2.977076,4.5972047,5.0609355,16.815678,16.622477,4.0920167,4.7391872,16.780783,4.731158,4.6562233,15.584796,-3.0576966,-3.3475304,4.9399576,17.18416],"xaxis":"x","y":[25.147835,9.594928,9.813636,9.454122,3.9549644,6.05243,5.8610854,9.03978,25.176819,-8.061363,9.062886,3.8036008,9.635308,11.883102,-8.061363,18.995394,3.6041436,9.621573,8.095722,9.943792,18.889307,18.696732,10.245858,8.287286,18.853558,9.024095,9.474419,6.0846996,11.685009,11.974955,9.252098,19.249119],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endl ...

# %%
# save the figure to file
visualization = topic_model.visualize_topics()

# Save the visualization as an image file with high resolution (e.g., 1920x1080)
visualization.write_image("topic_visualization.png", width=1920, height=1080)

# %%
topic_info = topic_model.get_topic_info()

# Save the data table to a text file
topic_info.to_csv("topic_data.txt", sep='\t', index=False)
